# %%
import pandas as pd

# %%
pf = pd.read_csv('train.csv')

# %%
import matplotlib.pyplot as plt

# %%
def bar_chart(ft):
    survived = train[train['Survived']==1][ft].value_counts()
    dead = train[train['Survived']==0][ft].value_counts()
    ret = pd.DataFrame([survived, dead])
    ret.index = ['Survived','Dead']
    ret.plot(kind='bar',stacked=True,figsize=(10,5))

# %%
bar_chart('Sex')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-4e8ec99bb58c> in <module>
# ----> 1 bar_chart('Sex')
#
# <ipython-input-4-e7abb6e6e7a1> in bar_chart(ft)
#       1 def bar_chart(ft):
# ----> 2     survived = train[train['Survived']==1][ft].value_counts()
#       3     dead = train[train['Survived']==0][ft].value_counts()
#       4     ret = pd.DataFrame([survived, dead])
#       5     ret.index = ['Survived','Dead']
#
# NameError: name 'train' is not defined

# %%
train = pd.read_csv('train.csv')

# %%
bar_chart('Sex')

# %%
bar_chart('Cabin')

# %%
bar_chart('Age')
